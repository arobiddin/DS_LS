# %% [markdown]
# <a href="https://colab.research.google.com/github/arobiddin/DS_LS/blob/main/04_VISUAL_AMALIYOT_04_distribution_JAVOBLAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 4-AMALIYOT. Distribution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Ushbu amaliyotda uybor.uz saytidan yuklab olingan ma'lumotlar tahlili bilan shu'gullanamiz.

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/uybor_scrapping.csv?raw=true")
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#    size  level  max_levels  price        lat        lng
# 0  57.0      4           4  52000  41.371471  69.281049
# 1  52.0      4           5  56000  41.291115  69.261104
# 2  42.0      4           4  37000  41.280784  69.223683
# 3  65.0      1           4  49500  41.290163  69.196862
# 4  70.0      3           5  55000  41.300156  69.210831

# %% [markdown]
# #### Yuqoridagi jadvalda Toshkent shahridagi sotildagian uylar haqida ma'lumotlar jamlangan.
#
# ### 1-VAZIFA. Uylarning narxi taqsimotini grafikda ko'rsating

# %%
#JAVOBINGIZNI SHUYERGA YOZING
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='price')
plt.show()

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='price')
plt.show()

# %% [markdown]
# ### Jadvalda 7000 dan oshiq uy bor, aksar uylarning narxi 200000$ dan kam. Keling noodatiy katta qiymatlarni tashlab yuboramiz va yuqoridagi chizmani qaytadan chizamiz.

# %%
#JAVOBINGIZNI SHUYERGA YOZING
df = df[df['price']<200000]
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='price')
plt.show()

# %%
#@title Kutilgan natija
df = df[df['price']<200000]
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='price')
plt.show()

# %% [markdown]
# ### 2-VAZIFA. Uylarning maydoni taqsimoti grafigini chizing

# %%
# JAVOB UCHUN JOY
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='size')
plt.show()

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='size')
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Uylarning xonalar soni taqsimotini chiqaring.

# %%
# JAVOB UCHUN JOY
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='rooms')
plt.show()

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='rooms')
plt.show()

# %% [markdown]
# 6 xonadan ortiq uylarni tashlab yuboramiz.

# %%
df = df[df['rooms']<7]

# %% [markdown]
# ### 4-VAZIFA. Uylarning narxi taqsimotini xonalar soniga bog'lab chiqaramiz.

# %%
# JAVOBNI SHUYERGA YOZING
sns.displot(data=df, x='price', hue="rooms", palette='Accent', height = 5, aspect=2)
plt.show()

# %%
#@title Kutilgan natija
sns.displot(data=df, x='price', hue='rooms', palette='Accent', height=5, aspect=2)
plt.show()

# %% [markdown]
# ### 4.1 Grafik tushunarsiz chiqdi. Keling faqatgina 1,2,3 xonali uylarning narx bo'yicha taqsimotini chizamiz.

# %%
# JAVOBNI SHUYERGA YOZING
sns.displot(data=df[df['rooms']<4], x='price', hue="rooms", multiple = "stack", height = 5, aspect=2)
plt.show()

# %%
#@title Kutilgan natija
sns.displot(data=df[df['rooms']<4], x='price', hue='rooms', multiple='stack', palette='Reds', height=5, aspect=2)
plt.show()

# %% [markdown]
# ### 5-VAZIFA. 4,5,6 xonali uylar uchun narx taqsimotini alohida grafiklarda chizing

# %%
# JAVOB UCHUN JOY
sns.displot(data=df[df['rooms']>=4], x='price', col="rooms", height = 5, aspect=1)
plt.show()

# %%
#@title Kutilgan natija
sns.displot(data=df[df['rooms']>3], x="price", col="rooms", height=5, aspect=1)
plt.show()

# %% [markdown]
# ## 6-VAZIFA. Uylarning maydoni taqsimoti KDE grafigini chizing

# %%
# JAVOB UCHUN JOY
sns.displot(data=df, x='size', kind='kde', height = 5, aspect=2)
plt.show()

# %%
#@title Kutilgan natija

sns.displot(data=df, x='size', kind='kde', height=5, aspect=2) # height va aspect grafik hajmini berish uchun
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 7-VAZIFA. Uylarning maydoni taqsimotini KDE va taqsimotini birlashtirib chizing.

# %%
# JAVOB UCHUN JOY
sns.displot(data=df, x='size', kde=True, height = 5, aspect=2)
plt.show()

# %%
#@title Kutilgan natija
sns.displot(data=df, x='size', kde=True, height=5, aspect=2)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 8-VAZIFA. Uylarning narxi va xonalari soni uchun (2,3,5 xonali) KDE chizing.

# %%
df[(df['rooms']==2) | (df['rooms']==3) | (df['rooms']==5)]
# Out:
#                                                location           district  \
# 0     город Ташкент, Юнусабадский район, Юнусабад 8-...       Юнусабадский
# 1     город Ташкент, Яккасарайский район, 1-й тупик ...      Яккасарайский
# 2     город Ташкент, Чиланзарский район, Чиланзар 2-...       Чиланзарский
# 3     город Ташкент, Чиланзарский район, Чиланзар 9-...       Чиланзарский
# 4     город Ташкент, Чиланзарский район, площадь Актепа       Чиланзарский
# ...                                                 ...                ...
# 7411  город Ташкент, Мирзо-Улугбекский район, Ц-1 ка...  Мирзо-Улугбекский
# 7412   город Ташкент, Яшнободский район, Базар Кадышева        Яшнободский
# 7413  город Ташкент, Мирабадский район, Айбека (пр-т...        Мирабадский
# 7417  город Ташкент, Яшнободский район, 1-й проезд А...        Яшнободский
# 7418  город Ташкент, Шайхантахурский район, Зульфиях...    Шайхантахурский
#
#       rooms  size  level  max_levels  price        lat        lng
# 0         3  57.0      4           4  52000  41.371471  69.281049
# 1         2  52.0      4           5  56000  41.291115  69.261104
# 2         2  42.0      4           4  37000  41.280784  69.223683
# 3         3  65.0      1           4  49500  41.290163  69.196862
# 4         3  70.0      3           5  55000  41.300156  69.210831
# ...     ...   ...    ...         ...    ...        ...        ...
# 7411      3  85.0      4           4  90000  41.311581  69.289848
# 7412      3  70.0      2           4  36500  41.285355  69.349190
# 7413      3  80.0      4           4  57000  41.298383  69.273072
# 7417      2  49.0      1           4  32000  41.289606  69.343485
# 7418      2  64.0      3           9  40000  41.331415  69.268901
#
# [5205 rows x 9 columns]

# %%
# JAVOB UCHUN JOY
plt.figure(figsize=(10,5))
sns.kdeplot(data=df[(df['rooms']==2) | (df['rooms']==3) | (df['rooms']==5)], x='price', hue='rooms', shade=True)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-47-d21242e7000d>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[(df['rooms']==2) | (df['rooms']==3) | (df['rooms']==5)], x='price', hue='rooms', shade=True)

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,5))
sns.kdeplot(data=df[df['rooms'].isin([2,3,5])], x='price', hue='rooms', shade=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 9-VAZIFA. Uylarning maydoni uchun kumulyativ taqsimot grafigini chizing (CDF)

# %%
# JAVOB UCHUN JOY
sns.displot(data=df, x="size", kind="ecdf", height=5, aspect=2)
plt.grid(which='both') # setka (major, minor, both) qiymatlarini berib ko'ring
plt.minorticks_on()
plt.show()

# %%
#@title Kutilgan natija
sns.displot(data=df, x="size", kind="ecdf", height=5, aspect=2)
plt.xticks(rotation=90)
plt.grid(which='both') # setka (major, minor, both) qiymatlarini berib ko'ring
plt.minorticks_on()
plt.show()

# %% [markdown]
# ## 10-VAZIFA. Yuqoridagi grafikni uylarning narxi uchun chizing.

# %%
# JAVOB UCHUN JOY
sns.displot(data=df, x="price", kind="ecdf", height=5, aspect=2)
plt.grid(which='both') # setka (major, minor, both) qiymatlarini berib ko'ring
plt.minorticks_on()
plt.show()

# %%
#@title Natija
sns.displot(data=df, x="price", kind="ecdf", height=5, aspect=2)
plt.xticks(rotation=90)
plt.grid(which='both') # setka (major, minor, both) qiymatlarini berib ko'ring
plt.minorticks_on()
plt.show()
