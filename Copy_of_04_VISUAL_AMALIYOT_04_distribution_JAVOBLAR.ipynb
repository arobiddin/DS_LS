# %% [markdown]
# <a href="https://colab.research.google.com/github/arobiddin/DS_LS/blob/main/Copy_of_04_VISUAL_AMALIYOT_04_distribution_JAVOBLAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 4-AMALIYOT. Distribution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Ushbu amaliyotda uybor.uz saytidan yuklab olingan ma'lumotlar tahlili bilan shu'gullanamiz.

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/uybor_scrapping.csv?raw=true")
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#    size  level  max_levels  price        lat        lng
# 0  57.0      4           4  52000  41.371471  69.281049
# 1  52.0      4           5  56000  41.291115  69.261104
# 2  42.0      4           4  37000  41.280784  69.223683
# 3  65.0      1           4  49500  41.290163  69.196862
# 4  70.0      3           5  55000  41.300156  69.210831

# %% [markdown]
# #### Yuqoridagi jadvalda Toshkent shahridagi sotildagian uylar haqida ma'lumotlar jamlangan.
#
# ## 1-VAZIFA. Jadvaldan xonalari 5 xonadan ko'p bo'lgan, narxi 200000 mingdan, maydoni 250kv.m dan ortiq bo'lgan uylarni tashlab yuboring

# %%
#JAVOBINGIZNI SHUYERGA YOZING
#Shart bo'yicha:
df1 = df[(df['rooms']<=5) & (df['price']<=200000) & (df['size']<=250)]
df1.shape
# Out:
# (7223, 9)

# %%
#@title Natija
df=df[df['rooms']<6]
df=df[df['size']<250]
df=df[df['price']<200000]
df.shape
# Out:
# (7216, 9)

# %% [markdown]
# ## 2-VAZIFA. `subplot` yordamida uylarning narxi va xonalar soni taqsimoti grafiklarini yonma yon chizing

# %%
#JAVOBINGIZNI SHUYERGA YOZING
plt.figure(figsize=(15,10))
plt.subplot(2,2,1) # 2 - j8mi qatorlar soni, 1 - jami ustunlar soni, 1-grafik
sns.histplot(data=df1, x='price')
plt.subplot(2,2,2)
sns.histplot(data=df1, x='rooms')
plt.show()

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(data=df, x='price')
plt.subplot(1,2,2)
sns.histplot(data=df, x='size')
plt.show()

# %% [markdown]
# ### 2-VAZIFA. Uylarning narxi taqsimoti va narx va maydoni o'rtasidagi bog'liqlik grafiklarini bitta chizmada ustma ust chiqaring.

# %%
# JAVOB UCHUN JOY
fig, ax = plt.subplots(2, 1, figsize=(7, 10))
# Umumiy chizmaga nom:
fig.suptitle("Toshkent uylarining narxi taqsimoti va narx va maydoni o'rtasidagi bog'liqlik grafiklari")
sns.histplot(ax=ax[0], data=df, x='price')
sns.scatterplot(ax=ax[1], data=df, x='size', y='price')
plt.show()

# %%
#@title Kutilgan natija
fig, ax = plt.subplots(2, 1, figsize=(10,10))
# Umumiy chizma nomini beramiz:
sns.histplot(ax=ax[0], data=df, x='price')
sns.scatterplot(ax=ax[1], data=df, x=df['size'], y=df['price'])
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Quyidagi grafikni chizing. Ahamiyat bering, oxirgi grafikda tumanlar bo'yicha uylarning o'rtacha narxi tasvirlangan.

# %%
# JAVOB UCHUN JOY
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
plt.title("Uylarning narxi bo'yicha taqsimoti")
sns.histplot(data=df1, x='price')
plt.subplot(2,2,2)
plt.title("Uylarning maydoni bo'yicha taqsimoti")
sns.histplot(data=df1, x='size')
plt.subplot(2,2,3)
plt.title("Uylarning narxi va maydoni o'rtasidagi bog'liqlik")
sns.scatterplot(data=df1, x='size', y='price')
plt.subplot(2,2,4)
plt.title("Uylarning tumanlar bo'yicha uylar taqsimoti")
sns.barplot(x=df1['district'], y=df1['price'])
plt.xticks(rotation=90)
plt.show()

# %%
#@title Kutilgan natija

# Tumanlar bo'yicha jamlangan df
distdf = df.groupby('district').mean()

#Grafiklarni chizamiz
fig, ax = plt.subplots(2, 2, figsize=(15,10))
# Umumiy chizma nomini beramiz:
sns.histplot(ax=ax[0, 0], data=df, x='price')
sns.histplot(ax=ax[0, 1], data=df, x='size')
sns.scatterplot(ax=ax[1, 0], data=df, x=df['size'], y=df['price'])
sns.barplot(ax=ax[1, 1], x=distdf.index, y=distdf['price'])
# Har bir grafik uchun nom:
ax[0,0].set_title("Uylarning narxi bo'yicha taqsimoti")
ax[0,1].set_title("Uylarning maydoni bo'yicha taqsimoti")
ax[1,0].set_title("Uylarning narxi va maydoni o'rtasioda bog'liqlik")
ax[1,1].set_title("Tumanlar bo'yicha o'rtacha narxlar")
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-39-f6f244c0e7ae>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   distdf = df.groupby('district').mean()
